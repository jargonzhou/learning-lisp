# %% [markdown]
# # common-lisp-jupyter

# %%
(+ 1 1)
# Out:
# 2

# %%
(format t "~a~%" "Hello, Common Lisp!")
# Out:
# nil
# Hello, Common Lisp!

# %% [markdown]
# # With Lisp Files

# %%
(load "common")
(cl-common:hello)
# Out:
# t
# "Hello, Common!"
# "Hello, Common!"

# %% [markdown]
# # Help

# %%
(setf x (list 1 2 3))

(describe x)

; an interactive version of describe
; (inspect x)
# Out:
# (1 2 3)
# ; file: CELL:1374963470.LISP.NEWEST
# ; in: setf x
# ;     (SETF X (LIST 1 2 3))
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user::x
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     x
# ;   caught 1 WARNING condition
#
# ; file: CELL:1374963470.LISP.NEWEST
# ; in: describe x
# ;     (DESCRIBE X)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user::x
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     x
# ;   caught 1 WARNING condition
# (1 2 3)
#   [list]

# %% [markdown]
# # shasht
# - https://github.com/yitzchak/shasht
# Common Lisp JSON reading and writing for the Kzinti.

# %%
(ql:quickload :shasht)
# Out:
# To load "shasht":
#   Load 1 ASDF system:
#     shasht
# (:shasht)
# ; Loading "shasht"

# %%
(shasht:write-json `(:object-plist "foo" "bar" "quux" 1.23) t)
# Out:
# (:object-plist "foo" "bar" "quux" 1.23)
# {
#   "foo": "bar",
#   "quux": 1.23
# }

# %%
(jupyter:json `(:object-plist "foo" "bar" "quux" (:object-plist "a" 1 "b" 2)) :expanded t :display t :id "a")

# %% [markdown]
# # Debug

# %%
; quicklisp\dists\quicklisp\software\common-lisp-jupyter-20241012-git\examples\debug.ipynb
(declaim (optimize (debug 3)
                   (safety 3)
                   (speed 0)))

(defun fu (x)
  (print "1")
  (break) ;; break
  (print "2")
  (+ x y))
# Out:
# nil
# fu
# ; file: CELL:3737900096.LISP.NEWEST
# ; in: declaim (optimize (debug 3) (safety 3) (speed 0))
# ;     (DECLAIM (OPTIMIZE (DEBUG 3) (SAFETY 3) (SPEED 0)))
# ;
# ; caught style-warning:
# ;   DECLAIM where DECLARE was probably intended
# ;
# ; compilation unit finished
# ;   caught 1 STYLE-WARNING condition
#
# ; file: CELL:3737900096.LISP.NEWEST
# ; in: defun fu
# ;     (+ X Y)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user::y
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     y
# ;   caught 1 WARNING condition

# %%
; (fu 7)
; (step (fu 7))


;; 0: [CONTINUE] Return from BREAK.

# %% [markdown]
# # Lisp Image

# %%
; WARN: The variable *modules* is deprecated.
*modules*
# Out:
# ("SB-INTROSPECT" "URI" "IRONCLAD" "SB-ROTATE-BYTE" "SB-BSD-SOCKETS" "SB-POSIX"
#  "ASDF" "asdf" "UIOP" "uiop")

# %%
; current package
*package*
# Out:
# #<package "COMMON-LISP-USER">

# %%
; returns a fresh list of all registered packages
(list-all-packages)
# Out:
# (#<package "SB-MOP"> #<package "CFFI-GROVEL"> #<package "QL-SETUP">
#  #<package "BABEL-ENCODINGS"> #<package "ASDF/OPERATION"> #<package "QL-CDB">
#  #<package "SB-KERNEL"> #<package "TRIVIAL-MIMES"> #<package "SB-EVAL">
#  #<package "ALEXANDRIA"> #<package "SB-ROTATE-BYTE">
#  #<package "JUPYTER/WIDGETS"> #<package "TRIVIAL-INDENT"> #<package "SB-DEBUG">
#  #<package "UIOP/IMAGE"> #<package "SB-WALKER"> #<package "CFFI">
#  #<package "KEYWORD"> #<package "QL-INFO"> #<package "ACCLIMATION">
#  #<package "SB-FORMAT"> #<package "SB-INTROSPECT"> #<package "CFFI-FEATURES">
#  #<package "CFFI-TOOLCHAIN"> #<package "CL-BASE64-SYSTEM">
#  #<package "ASDF/FORCING"> #<package "SB-C"> #<package "SB-EXT">
#  #<package "QL-MINITAR"> #<package "ASDF/PACKAGE-INFERRED-SYSTEM">
#  #<package "SB-REGALLOC"> #<package "SB-BROTHERTREE">
#  #<package "JUPYTER/COMMON-LISP"> #<package "ASDF/PARSE-DEFSYSTEM">
#  #<package "ASDF/USER"> #<package "QL-ALLEGRO"> #<package "SB-LOCKLESS">
#  #<package "PURI"> #<package "JUPYTER/CONVERT"> #<package "IRONCLAD-SYSTEM">
#  #<package "CL-COMMON"> #<package "QL-CCL"> #<package "UIOP/UTILITY">
#  #<package "SB-WIN32"> #<package "CLOSER-COMMON-LISP">
#  #<package "QUICKLISP-CLIENT"> #<package "QL-MEZZANO"> #<package "QL-ABCL">
#  #<package "PURI-SYSTEM"> #<package "QL-CMUCL"> #<package "ASDF/FOOTER">
#  #<package "ASDF/INTERFACE"> #<package "ASDF/SYSTEM-REGISTRY">
#  #<package "SB-PCL"> #<package "QL-IMPL"> #<package "SB-SYS">
#  #<package "ASDF/ACTION"> #<package "QL-CLASP"> #<package "SB-BIGNUM">
#  #<package "ASDF/CONCATENATE-SOURCE"> #<package "ASDF/SYSTEM">
#  #<package "SB-PROFILE"> #<package "ASDF/BUNDLE">
#  #<package "TRIVIAL-GRAY-STREAMS"> #<package "QL-MKCL">
#  #<package "ASDF/BACKWARD-INTERFACE"> #<package "UIOP/PACKAGE">
#  #<package "UIOP/CONFIGURATION"> #<package "MULTILANG-DOCUMENTATION">
#  #<package "UIOP/OS"> #<package "QL-ECL"> #<package "QL-HTTP">
#  #<package "SB-ASSEM"> #<package "SHASHT"> #<package "ECLECTOR.READER">
#  #<package "ASDF/UPGRADE"> #<package "SB-BSD-SOCKETS-INTERNAL">
#  #<package "QL-GUNZIPPER"> #<package "SB-UNIX">
#  #<package "DOCUMENTATION-UTILS"> #<package "TRIVIAL-GARBAGE">
#  #<package "NONTRIVIAL-GRAY-STREAMS"> #<package "SB-FASL">
#  #<package "SYSTEM-LOCALE"> #<package "SB-GRAY"> #<package "DISSECT">
#  #<package "QL-SCL"> #<package "ASDF/FIND-SYSTEM"> #<package "COMMON-LISP">
#  #<package "SB-SEQUENCE"> #<package "CL-BASE64"> #<package "IRONCLAD">
#  #<package "ECLECTOR.READTABLE"> #<package "QL-DIST-USER">
#  #<package "QL-NETWORK"> #<package "UIOP/BACKWARD-DRIVER">
#  #<package "ASDF/OPERATE"> #<package "SB-DISASSEM"> #<package "UIOP/VERSION">
#  #<package "UIOP/LAUNCH-PROGRAM"> #<package "COMMON-LISP-USER">
#  #<package "IRONCLAD-VM"> #<package "SB-BSD-SOCKETS"> #<package "QL-LISPWORKS">
#  #<package "QL-DIST"> #<package "ASDF/SOURCE-REGISTRY">
#  #<package "UIOP/FILESYSTEM"> #<package "JUPYTER"> #<package "ALEXANDRIA-2">
#  #<package "PZMQ"> #<package "LANGUAGE-CODES"> #<package "GLOBAL-VARS">
#  #<package "BORDEAUX-THREADS"> #<package "JUPYTER/LAB-EXTENSION">
#  #<package "CLOSER-MOP"> #<package "ASDF/FIND-COMPONENT">
#  #<package "UIOP/STREAM"> #<package "ECLECTOR.PARSE-RESULT">
#  #<package "ASDF/OUTPUT-TRANSLATIONS"> #<package "QL-IMPL-UTIL">
#  #<package "UIOP/RUN-PROGRAM"> #<package "SB-LOOP"> #<package "SB-UNICODE">
#  #<package "QL-PROGRESS"> #<package "SB-INT"> #<package "ASDF/COMPONENT">
#  #<package "SB-THREAD"> #<package "QL-SBCL">
#  #<package "ECLECTOR.READTABLE.SIMPLE"> #<package "ASDF/LISP-ACTION">
#  #<package "UIOP/PATHNAME"> #<package "IMPL-SPECIFIC-GRAY">
#  #<package "SB-APROF"> #<package "INDENTIFY"> #<package "QL-CLISP">
#  #<package "ECLECTOR.BASE"> #<package "SB-POSIX"> #<package "QL-CONFIG">
#  #<package "UIOP/LISP-BUILD"> #<package "QL-UTIL"> #<package "SB-PRETTY">
#  #<package "UIOP/DRIVER"> #<package "BT2"> #<package "IRONCLAD-TESTS">
#  #<package "SB-ALIEN-INTERNALS"> #<package "ASDF/PLAN">
#  #<package "UIOP/COMMON-LISP"> #<package "ASDF/BACKWARD-INTERNALS">
#  #<package "SB-VM"> #<package "ASDF/SESSION"> #<package "SB-X86-64-ASM">
#  #<package "CFFI-SYS"> #<package "QL-BUNDLE"> #<package "SB-ALIEN">
#  #<package "CLOSER-COMMON-LISP-USER"> #<package "SB-IMPL">
#  #<package "JUPYTER/MARKDOWN-FORMATTER"> #<package "TRIVIAL-DO">
#  #<package "BABEL"> #<package "SB-DI">)

# %%
; features
*features*
# Out:
# (:gray-streams-line-length :gray-streams-interactive
#  :gray-streams-file-position/optional :gray-streams-file-position
#  :gray-streams-sequence/optional :gray-streams-sequence
#  :gray-streams-directionp :ironclad-assembly :ironclad-sb-vm-ea
#  :ironclad-fast-mod64-arithmetic :ironclad-fast-mod32-arithmetic :closer-mop
#  :bordeaux-threads :global-vars cffi-features:flat-namespace
#  cffi-features:x86-64 cffi-features:windows :cffi cffi-sys::flat-namespace
#  alexandria::sequence-emptyp :windows :thread-support :quicklisp :asdf3.3
#  :asdf3.2 :asdf3.1 :asdf3 :asdf2 :asdf :os-windows :non-base-chars-exist-p
#  :asdf-unicode :arena-allocator :x86-64 :gencgc :64-bit :ansi-cl :common-lisp
#  :ieee-floating-point :little-endian :package-local-nicknames :sb-ldb
#  :sb-package-locks :sb-safepoint :sb-thread :sb-unicode :sbcl :win32)

# %%
; a pathname, used as the default whenever a function needs a default pathname and one is not supplied.
*default-pathname-defaults*
# Out:
# #P"d:/workspace/github/learning-lisp/CommonLisp/tools/"

# %%
*load-pathname*
*load-truename*
# Out:
# #P"CELL:61104853.LISP.NEWEST"
# #P"C:/Users/zhouj/AppData/Local/Temp/61104853.lisp"

# %% [markdown]
# # Inspection

# %%
; search every registered package for symbols: use string=
(find-all-symbols 'find-if)
(find-all-symbols "find-if") ; not found
(find-all-symbols "FIND-IF")

; locate a symbol. second value: internal, external, inherited(through use-package)
(find-symbol "FIND-IF")
(find-symbol "find-if") ; not found
# Out:
# (sb-sequence:find-if find-if)
# nil
# (sb-sequence:find-if find-if)
# find-if
# :inherited
# nil
# nil

# %%
; search for interned symbols
(apropos "find-if")

(apropos-list "find-if")
# Out:
# (find-if sb-sequence:find-if sb-c::find-if-derive-type-optimizer
#          sb-impl::find-if-in-closure sb-c::find-if-ir2-hook-optimizer
#          find-if-not sb-sequence:find-if-not
#          sb-c::find-if-not-derive-type-optimizer)
# find-if (fbound)
# sb-sequence:find-if (fbound)
# sb-c::find-if-derive-type-optimizer (fbound)
# sb-impl::find-if-in-closure (fbound)
# sb-c::find-if-ir2-hook-optimizer (fbound)
# find-if-not (fbound)
# sb-sequence:find-if-not (fbound)
# sb-c::find-if-not-derive-type-optimizer (fbound)

# %%
(load "common")
(cl-common:hello)

; list all symbols in a specific package
(do-external-symbols (s (find-package 'cl-common))
  (cl-common:dump-symbol s))
# Out:
# t
# warning: CL-COMMON also exports the following symbols:
#   (cl-common:symbol-function-or-nil)
# See also:
#   The ANSI Standard, Macro defpackage
#   The SBCL Manual, Variable *on-package-variance*
# "Hello, Common!"
# nil
# "Hello, Common!" dump-symbol [FUNCTION]
#  "Dump symbols."
#
# hello-macro [MACRO]
#  "Demo macro: hello-macro."
#
# symbol-function-or-nil [FUNCTION]
#  compiled-function
#
# hello [FUNCTION]
#  "Demo function: hello."

# %%
; Common Lisp exporting symbols from packages
; https://stackoverflow.com/questions/9743056/common-lisp-exporting-symbols-from-packages

; FIXME
; (do-all-symbols (sym (find-package :foo)) (export sym))
; (let ((pack (find-package :foo)))
;   (do-all-symbols (sym pack) (when (eql (symbol-package sym) pack) (export sym))))

# %% [markdown]
# # Packages

# %% [markdown]
# ## On Lisp - Appendix: Packages

# %%
; current package
*package*
# Out:
# #<package "COMMON-LISP-USER">

# %%
; package name: a string
(package-name *package*)
# Out:
# "COMMON-LISP-USER"

# %% [markdown]
# ### Symbol Intern when read

# %%
; symbol interned when was read
(symbol-package 'foo)
# Out:
# #<package "COMMON-LISP-USER">

# %%
(find-symbol "FOO" *package*)
# Out:
# foo
# :internal

# %%
(setq foo 99)
# Out:
# 99
# ; file: CELL:3463359710.LISP.NEWEST
# ; in: setq foo
# ;     (SETQ FOO 99)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user::foo
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     foo
# ;   caught 1 WARNING condition

# %% [markdown]
# ### Switch Packages

# %%
; switch to a new package, created if necessary
; (in-package 'mine :use 'common-lisp) ; ERROR

; delete package then make
(in-package :cl-user)
(if (find-package 'mine)
  (delete-package 'mine))
(make-package 'mine)

(in-package :mine)
(cl:use-package 'common-lisp 'mine)
# Out:
# #<package "COMMON-LISP-USER">
# nil
# #<package "MINE">
# #<common-lisp:package "MINE">
# t

# %%
*package*
# Out:
# #<package "MINE">

# %%
; foo ; interned

# %%
cl-user::foo
# Out:
# 99
# ; file: CELL:1873282603.LISP.NEWEST
# ; in:
# ;     FOO
# ; --> MULTIPLE-VALUE-PROG1
# ; ==>
# ;   (PROGN FOO)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user::foo
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     common-lisp-user::foo
# ;   caught 1 WARNING condition

# %% [markdown]
# ### Export Symbols

# %%
(in-package :cl-user)
(export 'bar)
(setq bar 5)
# Out:
# #<package "COMMON-LISP-USER">
# t
# 5
# ; file: CELL:623583550.LISP.NEWEST
# ; in: setq bar
# ;     (SETQ BAR 5)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user:bar
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     bar
# ;   caught 1 WARNING condition

# %%
(in-package :mine)
cl-user:bar
# Out:
# #<package "MINE">
# 5
# ; file: CELL:1336193489.LISP.NEWEST
# ; in:
# ;     BAR
# ; --> MULTIPLE-VALUE-PROG1
# ; ==>
# ;   (PROGN BAR)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user:bar
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     common-lisp-user:bar
# ;   caught 1 WARNING condition

# %% [markdown]
# ### Import Symbols

# %%
*package*
(import 'cl-user:bar)
bar
# Out:
# #<package "MINE">
# t
# 5
# ; file: CELL:2735914001.LISP.NEWEST
# ; in:
# ;     BAR
# ; --> MULTIPLE-VALUE-PROG1
# ; ==>
# ;   (PROGN BAR)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user:bar
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     bar
# ;   caught 1 WARNING condition

# %%
; name conflict
(import 'cl-user::foo)
# Out:
# t

# %%
; import all symbols
*package*
(use-package :cl-user)
cl-user::foo
bar
#'cons
# Out:
# #<package "MINE">
# t
# 99
# 5
# #<function cons>
# ; file: CELL:717979854.LISP.NEWEST
# ; in:
# ;     FOO
# ; --> MULTIPLE-VALUE-PROG1
# ; ==>
# ;   (PROGN FOO)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user::foo
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     foo
# ;   caught 1 WARNING condition
#
# ; file: CELL:717979854.LISP.NEWEST
# ; in:
# ;     BAR
# ; --> MULTIPLE-VALUE-PROG1
# ; ==>
# ;   (PROGN BAR)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user:bar
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     bar
# ;   caught 1 WARNING condition

# %% [markdown]
# ### Define Packages

# %%
; define packages
(in-package :cl-user)
(defpackage my-application
  (:use cl)
  (:nicknames app)
  (:export win lose draw))
(in-package :my-application)

(defun win () nil)
(defun lose () nil)
(defun draw () nil)
# Out:
# #<package "COMMON-LISP-USER">
# #<package "MY-APPLICATION">
# #<package "MY-APPLICATION">
# win
# lose
# draw

# %%
(in-package :mine)
(in-package :cl-user)
(export 'bar)
# Out:
# #<package "MINE">
# #<package "COMMON-LISP-USER">
# t

# %%
(in-package :cl-user)
(symbol-package 'bar)
(setq bar 5)

(if (find-package 'mine)
  (delete-package 'mine))
(make-package 'mine)

; (in-package :mine)
; (progn (cl:in-package :cl-user)
;        (cl:export 'bar))
# Out:
# #<package "COMMON-LISP-USER">
# #<package "COMMON-LISP-USER">
# 5
# t
# #<package "MINE">
# ; file: CELL:2976790412.LISP.NEWEST
# ; in: setq bar
# ;     (SETQ BAR 5)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user:bar
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     bar
# ;   caught 1 WARNING condition

# %%
cl-user::bar
# Out:
# 5
# ; file: CELL:3428426505.LISP.NEWEST
# ; in:
# ;     BAR
# ; --> MULTIPLE-VALUE-PROG1
# ; ==>
# ;   (PROGN BAR)
# ;
# ; caught warning:
# ;   undefined variable: common-lisp-user:bar
# ;
# ; compilation unit finished
# ;   Undefined variable:
# ;     bar
# ;   caught 1 WARNING condition

# %% [markdown]
# ### Keyword Symbols

# %%
(defpackage other
  (:use common-lisp)
  (:export noise))

(in-package :other)

(defun noise (animal)
  (case animal
    (dog 'woof)
    (cat 'meow)
    (pig 'oink)))

(noise 'pig)
# Out:
# #<package "OTHER">
# #<package "OTHER">
# noise
# oink

# %%
(in-package :cl-user)
(other:noise 'pig)
# Out:
# #<package "COMMON-LISP-USER">
# nil

# %%
(if (find-package 'other)
  (delete-package 'other))

(defpackage other
  (:use common-lisp)
  (:export noise))

(in-package :other)

; use keywords
(defun noise (animal)
  (case animal
    (:dog :woof)
    (:cat :meow)
    (:pig :oink)))

(in-package :cl-user)
(other:noise :pig)
# Out:
# t
# #<package "OTHER">
# #<package "OTHER">
# noise
# #<package "COMMON-LISP-USER">
# :oink

# %% [markdown]
# # Profiling

# %%
(time (apply #'+ '(1 2 3)))
(time (reduce #'+ '(1 2 3)))
# Out:
# 6
# 6
# Evaluation took:
#   0.000 seconds of real time
#   0.000000 seconds of total run time (0.000000 user, 0.000000 system)
#   100.00% CPU
#   4,526 processor cycles
#   0 bytes consed
#
# Evaluation took:
#   0.000 seconds of real time
#   0.000000 seconds of total run time (0.000000 user, 0.000000 system)
#   100.00% CPU
#   5,302 processor cycles
#   0 bytes consed

# %%
(require :sb-sprof)
# Out:
# ("SB-SPROF")
